# %%
# FinRL-Based Daily ETF Agent (Local Version)
# Author: Wilson & ChatGPT
# Goal: Use FinRL library to forecast daily ETF trading on QQQ/PSQ using PPO

# === Cell 1: SETUP & GENERAL IMPORTS ===
import os
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# Set root directory for saving results (outside 'agent')
ROOT_DIR = "../finrl_outputs"
os.makedirs(ROOT_DIR, exist_ok=True)

# === [next cell will handle FinRL module imports] ===

# %%
import warnings
warnings.filterwarnings("ignore")
# === Cell 2: FINRL MODULE IMPORTS ===
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %%
# === Custom Output Paths (adjusted for your folder layout) ===
import os
from finrl import config

# Redirect FinRL output dirs
config.DATA_SAVE_DIR = "../finrl_outputs/data"
config.TRAINED_MODEL_DIR = "../finrl_outputs/trained_models"
config.TENSORBOARD_LOG_DIR = "../finrl_outputs/tensorboard_logs"
config.RESULTS_DIR = "../finrl_outputs/results"

# Make sure all paths exist
os.makedirs(config.DATA_SAVE_DIR, exist_ok=True)
os.makedirs(config.TRAINED_MODEL_DIR, exist_ok=True)
os.makedirs(config.TENSORBOARD_LOG_DIR, exist_ok=True)
os.makedirs(config.RESULTS_DIR, exist_ok=True)

# %%
from datetime import datetime, timedelta

# === Cell X: DATA DOWNLOAD WITH AUTO-DATE RANGES ===

from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor

# Custom ETF list
tickers = ["QQQ", "SPY"]

# Dynamically calculate dates
today = datetime.today()
TRAIN_START_DATE = (today.replace(year=today.year - 20)).strftime("%Y-%m-%d")  # 20 years ago
TRAIN_END_DATE = (today.replace(year=today.year - 3)).strftime("%Y-%m-%d")     # 3 years ago
TEST_START_DATE = TRAIN_END_DATE
TEST_END_DATE = today.strftime("%Y-%m-%d")

# Download historical data
data_processor = YahooFinanceProcessor()
df_raw = data_processor.download_data(
    start_date=TRAIN_START_DATE,
    end_date=TEST_END_DATE,
    ticker_list=tickers,
    time_interval="1d"
)

df_raw.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# YF deprecation warning: set proxy via new config function: yf.set_proxy(proxy)
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-04-30 00:00:00 -> 2005-05-01 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-05-01 00:00:00 -> 2005-05-02 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-05-07 00:00:00 -> 2005-05-08 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-05-08 00:00:00 -> 2005-05-09 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-05-14 00:00:00 -> 2005-05-15 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-05-15 00:00:00 -> 2005-05-16 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-05-21 00:00:00 -> 2005-05-22 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-05-22 00:00:00 -> 2005-05-23 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-05-28 00:00:00 -> 2005-05-29 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-05-29 00:00:00 -> 2005-05-30 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-05-30 00:00:00 -> 2005-05-31 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-06-04 00:00:00 -> 2005-06-05 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-06-05 00:00:00 -> 2005-06-06 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-06-11 00:00:00 -> 2005-06-12 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-06-12 00:00:00 -> 2005-06-13 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-06-18 00:00:00 -> 2005-06-19 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-06-19 00:00:00 -> 2005-06-20 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-06-25 00:00:00 -> 2005-06-26 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-06-26 00:00:00 -> 2005-06-27 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-02 00:00:00 -> 2005-07-03 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-03 00:00:00 -> 2005-07-04 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-04 00:00:00 -> 2005-07-05 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-09 00:00:00 -> 2005-07-10 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-10 00:00:00 -> 2005-07-11 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-16 00:00:00 -> 2005-07-17 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-17 00:00:00 -> 2005-07-18 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-23 00:00:00 -> 2005-07-24 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-24 00:00:00 -> 2005-07-25 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-30 00:00:00 -> 2005-07-31 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-07-31 00:00:00 -> 2005-08-01 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-08-06 00:00:00 -> 2005-08-07 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-08-07 00:00:00 -> 2005-08-08 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-08-13 00:00:00 -> 2005-08-14 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-08-14 00:00:00 -> 2005-08-15 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-08-20 00:00:00 -> 2005-08-21 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-08-21 00:00:00 -> 2005-08-22 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-08-27 00:00:00 -> 2005-08-28 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-08-28 00:00:00 -> 2005-08-29 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-09-03 00:00:00 -> 2005-09-04 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-09-04 00:00:00 -> 2005-09-05 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-09-05 00:00:00 -> 2005-09-06 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-09-10 00:00:00 -> 2005-09-11 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-09-11 00:00:00 -> 2005-09-12 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-09-17 00:00:00 -> 2005-09-18 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-09-18 00:00:00 -> 2005-09-19 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-09-24 00:00:00 -> 2005-09-25 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-09-25 00:00:00 -> 2005-09-26 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-10-01 00:00:00 -> 2005-10-02 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-10-02 00:00:00 -> 2005-10-03 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-10-08 00:00:00 -> 2005-10-09 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-10-09 00:00:00 -> 2005-10-10 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-10-15 00:00:00 -> 2005-10-16 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-10-16 00:00:00 -> 2005-10-17 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-10-22 00:00:00 -> 2005-10-23 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-10-23 00:00:00 -> 2005-10-24 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-10-29 00:00:00 -> 2005-10-30 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-10-30 00:00:00 -> 2005-10-31 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-11-05 00:00:00 -> 2005-11-06 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-11-06 00:00:00 -> 2005-11-07 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-11-12 00:00:00 -> 2005-11-13 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-11-13 00:00:00 -> 2005-11-14 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-11-19 00:00:00 -> 2005-11-20 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-11-20 00:00:00 -> 2005-11-21 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-11-24 00:00:00 -> 2005-11-25 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-11-26 00:00:00 -> 2005-11-27 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-11-27 00:00:00 -> 2005-11-28 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-12-03 00:00:00 -> 2005-12-04 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-12-04 00:00:00 -> 2005-12-05 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-12-10 00:00:00 -> 2005-12-11 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-12-11 00:00:00 -> 2005-12-12 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-12-17 00:00:00 -> 2005-12-18 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-12-18 00:00:00 -> 2005-12-19 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-12-24 00:00:00 -> 2005-12-25 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-12-25 00:00:00 -> 2005-12-26 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-12-26 00:00:00 -> 2005-12-27 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-12-31 00:00:00 -> 2006-01-01 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-01 00:00:00 -> 2006-01-02 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-02 00:00:00 -> 2006-01-03 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-07 00:00:00 -> 2006-01-08 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-08 00:00:00 -> 2006-01-09 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-14 00:00:00 -> 2006-01-15 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-15 00:00:00 -> 2006-01-16 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-16 00:00:00 -> 2006-01-17 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-21 00:00:00 -> 2006-01-22 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-22 00:00:00 -> 2006-01-23 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-28 00:00:00 -> 2006-01-29 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-01-29 00:00:00 -> 2006-01-30 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-02-04 00:00:00 -> 2006-02-05 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-02-05 00:00:00 -> 2006-02-06 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-02-11 00:00:00 -> 2006-02-12 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-02-12 00:00:00 -> 2006-02-13 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-02-18 00:00:00 -> 2006-02-19 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-02-19 00:00:00 -> 2006-02-20 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-02-20 00:00:00 -> 2006-02-21 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-02-25 00:00:00 -> 2006-02-26 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-02-26 00:00:00 -> 2006-02-27 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-03-04 00:00:00 -> 2006-03-05 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-03-05 00:00:00 -> 2006-03-06 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-03-11 00:00:00 -> 2006-03-12 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-03-12 00:00:00 -> 2006-03-13 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-03-18 00:00:00 -> 2006-03-19 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-03-19 00:00:00 -> 2006-03-20 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-03-25 00:00:00 -> 2006-03-26 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-03-26 00:00:00 -> 2006-03-27 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-01 00:00:00 -> 2006-04-02 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-02 00:00:00 -> 2006-04-03 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-08 00:00:00 -> 2006-04-09 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-09 00:00:00 -> 2006-04-10 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-14 00:00:00 -> 2006-04-15 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-15 00:00:00 -> 2006-04-16 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-16 00:00:00 -> 2006-04-17 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-22 00:00:00 -> 2006-04-23 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-23 00:00:00 -> 2006-04-24 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-29 00:00:00 -> 2006-04-30 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-04-30 00:00:00 -> 2006-05-01 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-05-06 00:00:00 -> 2006-05-07 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-05-07 00:00:00 -> 2006-05-08 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-05-13 00:00:00 -> 2006-05-14 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-05-14 00:00:00 -> 2006-05-15 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-05-20 00:00:00 -> 2006-05-21 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-05-21 00:00:00 -> 2006-05-22 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-05-27 00:00:00 -> 2006-05-28 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-05-28 00:00:00 -> 2006-05-29 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-05-29 00:00:00 -> 2006-05-30 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-06-03 00:00:00 -> 2006-06-04 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-06-04 00:00:00 -> 2006-06-05 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-06-10 00:00:00 -> 2006-06-11 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-06-11 00:00:00 -> 2006-06-12 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-06-17 00:00:00 -> 2006-06-18 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-06-18 00:00:00 -> 2006-06-19 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['QQQ']: YFPricesMissingError('possibly delisted; no price data found  (1d 2006-06-24 00:00:00 -> 2006-06-25 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ...
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-12-15 00:00:00 -> 2024-12-16 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-12-21 00:00:00 -> 2024-12-22 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-12-22 00:00:00 -> 2024-12-23 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-12-25 00:00:00 -> 2024-12-26 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-12-28 00:00:00 -> 2024-12-29 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-12-29 00:00:00 -> 2024-12-30 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-01 00:00:00 -> 2025-01-02 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-04 00:00:00 -> 2025-01-05 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-05 00:00:00 -> 2025-01-06 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-09 00:00:00 -> 2025-01-10 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-11 00:00:00 -> 2025-01-12 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-12 00:00:00 -> 2025-01-13 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-18 00:00:00 -> 2025-01-19 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-19 00:00:00 -> 2025-01-20 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-20 00:00:00 -> 2025-01-21 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-25 00:00:00 -> 2025-01-26 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-01-26 00:00:00 -> 2025-01-27 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-02-01 00:00:00 -> 2025-02-02 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-02-02 00:00:00 -> 2025-02-03 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-02-08 00:00:00 -> 2025-02-09 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-02-09 00:00:00 -> 2025-02-10 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-02-15 00:00:00 -> 2025-02-16 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-02-16 00:00:00 -> 2025-02-17 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-02-17 00:00:00 -> 2025-02-18 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-02-22 00:00:00 -> 2025-02-23 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-02-23 00:00:00 -> 2025-02-24 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-03-01 00:00:00 -> 2025-03-02 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-03-02 00:00:00 -> 2025-03-03 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-03-08 00:00:00 -> 2025-03-09 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-03-09 00:00:00 -> 2025-03-10 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-03-15 00:00:00 -> 2025-03-16 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-03-16 00:00:00 -> 2025-03-17 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-03-22 00:00:00 -> 2025-03-23 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-03-23 00:00:00 -> 2025-03-24 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-03-29 00:00:00 -> 2025-03-30 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-03-30 00:00:00 -> 2025-03-31 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-04-05 00:00:00 -> 2025-04-06 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-04-06 00:00:00 -> 2025-04-07 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-04-12 00:00:00 -> 2025-04-13 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-04-13 00:00:00 -> 2025-04-14 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-04-18 00:00:00 -> 2025-04-19 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-04-19 00:00:00 -> 2025-04-20 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-04-20 00:00:00 -> 2025-04-21 00:00:00)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFPricesMissingError('possibly delisted; no price data found  (1d 2025-04-27 00:00:00 -> 2025-04-28 00:00:00)')
#    timestamp      close       high        low       open       volume  tic
# 0 2005-04-27  30.049006  30.177421  29.732251  29.852104  112539300.0  QQQ
# 1 2005-04-28  29.749380  30.091820  29.723698  29.894915   98181900.0  QQQ
# 2 2005-04-29  29.946287  30.014777  29.406945  29.963409  144435900.0  QQQ
# 3 2005-05-02  30.066149  30.186002  29.869247  30.049026   67648800.0  QQQ
# 4 2005-05-03  30.220238  30.331531  29.989091  30.006213  103428700.0  QQQ

# %%
print("Before feature engineering:")
print("  Total rows:", len(df_raw))
print("  Unique dates:", df_raw['date'].nunique())
print("  Unique tic-date pairs:", df_raw[['date', 'tic']].drop_duplicates().shape[0])
print("  Duplicated date-tic rows:", df_raw.duplicated(subset=['date', 'tic']).sum())
# Out:
# Before feature engineering:
#   Total rows: 10066
#   Unique dates: 5032
#   Unique tic-date pairs: 10064
#   Duplicated date-tic rows: 2

# %%
# === Cell X: FEATURE ENGINEERING (CLEANED AND FIXED) ===

from finrl.meta.preprocessor.preprocessors import FeatureEngineer

# === Clean up and normalize column names for stockstats ===
df_raw = df_raw.rename(columns={"timestamp": "date"})
df_raw.columns = [col.lower() for col in df_raw.columns]
df_raw["date"] = pd.to_datetime(df_raw["date"]).dt.strftime("%Y-%m-%d")

# 🧼 Drop duplicate (date, tic) rows to avoid merge/index mismatch
df_raw = df_raw.drop_duplicates(subset=["date", "tic"])

# === Define technical indicators to use ===
INDICATORS = ['macd', 'rsi_30', 'cci_30', 'dx_30']

# === Initialize FeatureEngineer ===
fe = FeatureEngineer(
    use_technical_indicator=True,
    tech_indicator_list=INDICATORS,
    use_turbulence=True,
    user_defined_feature=False
)

# === Apply feature engineering ===
processed = fe.preprocess_data(df_raw)
processed = processed.fillna(0).replace(np.inf, 0)

# === Preview output ===
print("Processed data shape:", processed.shape)
print("Columns:", processed.columns.tolist())
processed.head(30)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index
# Processed data shape: (10064, 12)
# Columns: ['date', 'close', 'high', 'low', 'open', 'volume', 'tic', 'macd', 'rsi_30', 'cci_30', 'dx_30', 'turbulence']
#           date      close       high        low       open       volume  tic  \
# 0   2005-04-27  30.049006  30.177421  29.732251  29.852104  112539300.0  QQQ
# 1   2005-04-27  79.445679  79.734196  78.614471  78.902988   84131900.0  SPY
# 2   2005-04-28  29.749380  30.091820  29.723698  29.894915   98181900.0  QQQ
# 3   2005-04-28  78.449654  79.466341  78.449654  79.184690   72481500.0  SPY
# 4   2005-04-29  29.946287  30.014777  29.406945  29.963409  144435900.0  QQQ
# 5   2005-04-29  79.514374  79.596810  78.291605  79.047248  103993800.0  SPY
# 6   2005-05-02  30.066149  30.186002  29.869247  30.049026   67648800.0  QQQ
# 7   2005-05-02  79.960930  79.967801  79.356411  79.734235   56026400.0  SPY
# 8   2005-05-03  30.220238  30.331531  29.989091  30.006213  103428700.0  QQQ
# 9   2005-05-03  80.098312  80.270050  79.473191  79.734230   86000300.0  SPY
# 10  2005-05-04  30.588348  30.673960  30.168863  30.211667   90480600.0  QQQ
# 11  2005-05-04  80.716560  80.888298  79.878481  80.132654   81055700.0  SPY
# 12  2005-05-05  30.614023  30.750999  30.417121  30.605464   79341700.0  QQQ
# 13  2005-05-05  80.689041  81.059994  80.194437  80.833300   96906700.0  SPY
# 14  2005-05-06  30.699633  30.836608  30.579780  30.793804   77310200.0  QQQ
# 15  2005-05-06  80.434883  81.053138  80.414275  81.011923   67415400.0  SPY
# 16  2005-05-09  30.845179  30.870864  30.528424  30.708203   66298400.0  QQQ
# 17  2005-05-09  80.936378  81.114987  80.407430  80.517339   43750500.0  SPY
# 18  2005-05-10  30.622585  30.785243  30.494169  30.699634   77194700.0  QQQ
# 19  2005-05-10  80.098282  80.716537  79.954023  80.620365   74613500.0  SPY
# 20  2005-05-11  30.776695  30.845181  30.220231  30.665402  131952400.0  QQQ
# 21  2005-05-11  80.537941  80.647855  79.583082  80.324988   91647400.0  SPY
# 22  2005-05-12  30.691082  30.990718  30.528425  30.845180  116602200.0  QQQ
# 23  2005-05-12  79.651779  80.778376  79.651779  80.592902   95086800.0  SPY
# 24  2005-05-13  31.024982  31.221885  30.725346  30.810958  133273500.0  QQQ
# 25  2005-05-13  79.493797  80.112053  78.861805  79.892229   85267000.0  SPY
# 26  2005-05-16  31.230434  31.281801  30.930802  31.024973   79093200.0  QQQ
# 27  2005-05-16  80.235687  80.263161  79.452565  79.480039   49207000.0  SPY
# 28  2005-05-17  31.418760  31.453005  30.999271  31.119124   91665900.0  QQQ
# 29  2005-05-17  80.771523  80.853953  79.796056  79.967793   61071800.0  SPY
#
#         macd     rsi_30      cci_30       dx_30  turbulence
# 0   0.000000   0.000000  -66.666667  100.000000         0.0
# 1   0.000000   0.000000  -66.666667  100.000000         0.0
# 2  -0.006722   0.000000  -66.666667  100.000000         0.0
# 3  -0.022347   0.000000  -66.666667  100.000000         0.0
# 4  -0.002460  40.470475  -80.000095  100.000000         0.0
# 5   0.004543  52.512791   26.181068  100.000000         0.0
# 6   0.003867  52.560351   85.579331   27.909258         0.0
# 7   0.032784  61.324577  126.699825   11.899453         0.0
# 8   0.013355  62.648514  118.176661    3.645660         0.0
# 9   0.052906  63.481239   99.597520   40.763273         0.0
# 10  0.034548  75.515793  154.165271   40.540702         0.0
# 11  0.090445  71.007609  123.258201   65.487186         0.0
# 12  0.048708  76.109612  125.998181   45.554430         0.0
# 13  0.111714  70.340081  109.810944   69.292053         0.0
# 14  0.061490  77.953935  114.775036   50.511474         0.0
# 15  0.112092  64.543063   89.367414   69.292053         0.0
# 16  0.076628  80.589384   98.900527   42.208758         0.0
# 17  0.135529  69.648856   93.021749   70.625052         0.0
# 18  0.074785  67.771758   67.126102   36.827200         0.0
# 19  0.107013  55.765921   31.499681   27.315472         0.0
# 20  0.080615  71.067530   58.102423    3.382169         0.0
# 21  0.108329  60.083721   30.203598    4.187484         0.0
# 22  0.079090  67.122741   75.975192   15.159456         0.0
# 23  0.059143  49.922962    3.158941   10.315379         0.0
# 24  0.095771  73.138405  113.704466   29.707742         0.0
# 25  0.012956  48.413058  -60.525265   21.972268         0.0
# 26  0.118920  75.940548  129.138220   32.895940         0.0
# 27  0.021214  55.021638    2.624632   15.084857         0.0
# 28  0.146037  78.106263  138.308557   41.061135         0.0
# 29  0.058968  58.950702   65.625242    6.889065         0.0

# %%
# === Cell X: ENVIRONMENT CONFIGURATION ===

# Count how many unique stocks we have
stock_dimension = len(processed.tic.unique())

# Compute state space size
state_space = 1 + 2 * stock_dimension + len(INDICATORS) * stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")

# Main env config (used in the pipeline)
env_kwargs = {
    "hmax": 100,
    "initial_amount": 2000,  # 🧠 You set this earlier
    "buy_cost_pct": 0.001,
    "sell_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4,
    "print_verbosity": 5,
}

# === Optional: Manual version with individual costs or share counts ===
# buy_cost_list = sell_cost_list = [0.001] * stock_dimension
# num_stock_shares = [0] * stock_dimension
# env_kwargs = {
#     "hmax": 100,
#     "initial_amount": 2000,
#     "num_stock_shares": num_stock_shares,
#     "buy_cost_pct": buy_cost_list,
#     "sell_cost_pct": sell_cost_list,
#     "state_space": state_space,
#     "stock_dim": stock_dimension,
#     "tech_indicator_list": INDICATORS,
#     "action_space": stock_dimension,
#     "reward_scaling": 1e-4
# }
# Out:
# Stock Dimension: 2, State Space: 13

# %%
# === Cell X: DRL ENSEMBLE AGENT SETUP ===



# Rebalance and validation windows (e.g. 63 days ~ 3 months of trading)
rebalance_window = 63
validation_window = 63

# Instantiate ensemble agent
ensemble_agent = DRLEnsembleAgent(
    df=processed,
    train_period=(TRAIN_START_DATE, TRAIN_END_DATE),
    val_test_period=(TEST_START_DATE, TEST_END_DATE),
    rebalance_window=rebalance_window,
    validation_window=validation_window,
    **env_kwargs
)

# === Optional: Use single DRL model directly ===
# from finrl.agents.stablebaselines3.models import DRLAgent
# from finrl.env.env_stock_trading import StockTradingEnv
#
# e_train_gym = StockTradingEnv(df=processed, **env_kwargs)
# agent = DRLAgent(e_train_gym)
# model_a2c = agent.get_model("a2c")
# trained_a2c = agent.train_model(
#     model=model_a2c,
#     tb_log_name='a2c',
#     total_timesteps=50000
# )

# %%
# === Cell X: MODEL CONFIGURATION ===

# A2C hyperparameters
A2C_model_kwargs = {
    'n_steps': 5,
    'ent_coef': 0.005,
    'learning_rate': 0.0007
}

# PPO hyperparameters
PPO_model_kwargs = {
    "ent_coef": 0.01,
    "n_steps": 2048,
    "learning_rate": 0.00025,
    "batch_size": 128
}

# DDPG hyperparameters
DDPG_model_kwargs = {
    "buffer_size": 10_000,
    "learning_rate": 0.0005,
    "batch_size": 64
}

# SAC hyperparameters
SAC_model_kwargs = {
    "batch_size": 64,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

# TD3 hyperparameters
TD3_model_kwargs = {
    "batch_size": 100,
    "buffer_size": 1000000,
    "learning_rate": 0.0001
}

# Total training timesteps for each model
timesteps_dict = {
    'a2c': 10_000,
    'ppo': 10_000,
    'ddpg': 10_000,
    'sac': 10_000,
    'td3': 10_000
}

# %%
# === Cell X: RUN ENSEMBLE STRATEGY ===

df_summary = ensemble_agent.run_ensemble_strategy(
    A2C_model_kwargs,
    PPO_model_kwargs,
    DDPG_model_kwargs,
    SAC_model_kwargs,
    TD3_model_kwargs,
    timesteps_dict
)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  20.564223074924595
# ======Model training from:  2005-04-27 to  2022-04-28
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/a2c\a2c_126_2
# ------------------------------------------
# | time/                 |                |
# |    fps                | 286            |
# |    iterations         | 100            |
# |    time_elapsed       | 1              |
# |    total_timesteps    | 500            |
# | train/                |                |
# |    entropy_loss       | -2.87          |
# |    explained_variance | -1.54e+04      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 99             |
# |    policy_loss        | -0.464         |
# |    reward             | -0.00016466224 |
# |    std                | 1.01           |
# |    value_loss         | 0.0265         |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 303          |
# |    iterations         | 200          |
# |    time_elapsed       | 3            |
# |    total_timesteps    | 1000         |
# | train/                |              |
# |    entropy_loss       | -2.88        |
# |    explained_variance | -2.25e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 199          |
# |    policy_loss        | 0.079        |
# |    reward             | 0.0006250189 |
# |    std                | 1.02         |
# |    value_loss         | 0.00723      |
# ----------------------------------------
# -------------------------------------------
# | time/                 |                 |
# |    fps                | 310             |
# |    iterations         | 300             |
# |    time_elapsed       | 4               |
# |    total_timesteps    | 1500            |
# | train/                |                 |
# |    entropy_loss       | -2.91           |
# |    explained_variance | -677            |
# |    learning_rate      | 0.0007          |
# |    n_updates          | 299             |
# |    policy_loss        | -0.0741         |
# |    reward             | -0.000113264825 |
# |    std                | 1.04            |
# |    value_loss         | 0.0053          |
# -------------------------------------------
# -------------------------------------------
# | time/                 |                 |
# |    fps                | 316             |
# |    iterations         | 400             |
# |    time_elapsed       | 6               |
# |    total_timesteps    | 2000            |
# | train/                |                 |
# |    entropy_loss       | -2.93           |
# |    explained_variance | -354            |
# |    learning_rate      | 0.0007          |
# |    n_updates          | 399             |
# |    policy_loss        | -0.134          |
# |    reward             | -0.000110721514 |
# |    std                | 1.05            |
# |    value_loss         | 0.00308         |
# -------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 317           |
# |    iterations         | 500           |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 2500          |
# | train/                |               |
# |    entropy_loss       | -2.95         |
# |    explained_variance | -1.07e+03     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 499           |
# |    policy_loss        | 0.0651        |
# |    reward             | 0.00043582305 |
# |    std                | 1.06          |
# |    value_loss         | 0.00417       |
# -----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 600      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | -4.72    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.00107 |
# |    reward             | 0.0      |
# |    std                | 1.06     |
# |    value_loss         | 1.03e-05 |
# ------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 318           |
# |    iterations         | 700           |
# |    time_elapsed       | 10            |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -2.98         |
# |    explained_variance | -166          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | -0.0389       |
# |    reward             | -9.351393e-05 |
# |    std                | 1.07          |
# |    value_loss         | 0.00369       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 317           |
# |    iterations         | 800           |
# |    time_elapsed       | 12            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -2.99         |
# |    explained_variance | -492          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | 0.0434        |
# |    reward             | -7.481245e-05 |
# |    std                | 1.08          |
# |    value_loss         | 0.0122        |
# -----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 900      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | 3.81e-06 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0197   |
# |    reward             | 0.0      |
# |    std                | 1.09     |
# |    value_loss         | 8.64e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 317      |
# |    iterations         | 1000     |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -3.03    |
# |    explained_variance | -58.2    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.157   |
# |    reward             | 0.0      |
# |    std                | 1.1      |
# |    value_loss         | 0.00171  |
# ------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 319           |
# |    iterations         | 1100          |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 5500          |
# | train/                |               |
# |    entropy_loss       | -3.06         |
# |    explained_variance | -3.4          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1099          |
# |    policy_loss        | -0.0508       |
# |    reward             | 0.00025579648 |
# |    std                | 1.12          |
# |    value_loss         | 0.000563      |
# -----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 1200     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -3.07    |
# |    explained_variance | -7.99    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.556   |
# |    reward             | 0.0      |
# |    std                | 1.12     |
# |    value_loss         | 0.0163   |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 319       |
# |    iterations         | 1300      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -3.1      |
# |    explained_variance | -107      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 0.0264    |
# |    reward             | 0.0003308 |
# |    std                | 1.14      |
# |    value_loss         | 0.00347   |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 318          |
# |    iterations         | 1400         |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 7000         |
# | train/                |              |
# |    entropy_loss       | -3.11        |
# |    explained_variance | -3.67e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1399         |
# |    policy_loss        | -0.154       |
# |    reward             | 0.0012834709 |
# |    std                | 1.15         |
# |    value_loss         | 0.00681      |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 318      |
# |    iterations         | 1500     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -3.13    |
# |    explained_variance | -126     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.00148 |
# |    reward             | 0.0      |
# |    std                | 1.16     |
# |    value_loss         | 0.000884 |
# ------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 312          |
# |    iterations         | 1600         |
# |    time_elapsed       | 25           |
# |    total_timesteps    | 8000         |
# | train/                |              |
# |    entropy_loss       | -3.15        |
# |    explained_variance | -18.9        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1599         |
# |    policy_loss        | -0.108       |
# |    reward             | -6.60835e-05 |
# |    std                | 1.17         |
# |    value_loss         | 0.00116      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 313         |
# |    iterations         | 1700        |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -3.16       |
# |    explained_variance | -126        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | -0.0021     |
# |    reward             | 0.002094165 |
# |    std                | 1.18        |
# |    value_loss         | 0.00164     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 314          |
# |    iterations         | 1800         |
# |    time_elapsed       | 28           |
# |    total_timesteps    | 9000         |
# | train/                |              |
# |    entropy_loss       | -3.19        |
# |    explained_variance | -653         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1799         |
# |    policy_loss        | 0.0784       |
# |    reward             | 0.0012143229 |
# |    std                | 1.19         |
# |    value_loss         | 0.00817      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 315          |
# |    iterations         | 1900         |
# |    time_elapsed       | 30           |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -3.22        |
# |    explained_variance | -459         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# |    policy_loss        | 0.221        |
# |    reward             | 0.0006346367 |
# |    std                | 1.21         |
# |    value_loss         | 0.00419      |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 315         |
# |    iterations         | 2000        |
# |    time_elapsed       | 31          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -3.22       |
# |    explained_variance | -75.8       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | 0.0772      |
# |    reward             | 0.000112677 |
# |    std                | 1.21        |
# |    value_loss         | 0.000819    |
# ---------------------------------------
# ======a2c Validation from:  2022-04-28 to  2022-07-29
# a2c Sharpe Ratio:  -0.09517874879363386
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/ddpg\ddpg_126_1
# day: 4280, episode: 5
# begin_total_asset: 2000.00
# end_total_asset: 20498.62
# total_reward: 18498.62
# total_cost: 1.98
# total_trades: 6917
# Sharpe: 0.749
# =================================
# ======ddpg Validation from:  2022-04-28 to  2022-07-29
# ddpg Sharpe Ratio:  0.0
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/td3\td3_126_1
# ======td3 Validation from:  2022-04-28 to  2022-07-29
# td3 Sharpe Ratio:  -0.0333947285896762
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/sac\sac_126_1
# day: 4280, episode: 10
# begin_total_asset: 2000.00
# end_total_asset: 1535.67
# total_reward: -464.33
# total_cost: 3378.59
# total_trades: 6822
# Sharpe: 0.006
# =================================
# ======sac Validation from:  2022-04-28 to  2022-07-29
# sac Sharpe Ratio:  -0.07744881851567136
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/ppo\ppo_126_1
# --------------------------------------
# | time/              |               |
# |    fps             | 454           |
# |    iterations      | 1             |
# |    time_elapsed    | 4             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | -6.599819e-05 |
# --------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 416            |
# |    iterations           | 2              |
# |    time_elapsed         | 9              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.004368347    |
# |    clip_fraction        | 0.0331         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.84          |
# |    explained_variance   | -12.1          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0449        |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00829       |
# |    reward               | -4.1811338e-05 |
# |    std                  | 0.999          |
# |    value_loss           | 0.0353         |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 3            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0050767455 |
# |    clip_fraction        | 0.0248       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -10.8        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0338      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00775     |
# |    reward               | 0.0          |
# |    std                  | 0.997        |
# |    value_loss           | 0.013        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 390           |
# |    iterations           | 4             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.0052154996  |
# |    clip_fraction        | 0.0346        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | -4.51         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0607       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.0126       |
# |    reward               | -6.895568e-05 |
# |    std                  | 1             |
# |    value_loss           | 0.0065        |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 393          |
# |    iterations           | 5            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.006919737  |
# |    clip_fraction        | 0.0639       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -11.7        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0463      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.013       |
# |    reward               | 0.0010013672 |
# |    std                  | 1            |
# |    value_loss           | 0.00436      |
# ------------------------------------------
# ======ppo Validation from:  2022-04-28 to  2022-07-29
# ppo Sharpe Ratio:  -0.2685824745059284
# ======Best Model Retraining from:  2005-04-27 to  2022-07-29
# ======Trading from:  2022-07-29 to  2022-10-27
# ============================================
# turbulence_threshold:  20.564223074924595
# ======Model training from:  2005-04-27 to  2022-07-29
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/a2c\a2c_189_1
# ----------------------------------------
# | time/                 |              |
# |    fps                | 336          |
# |    iterations         | 100          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -2.85        |
# |    explained_variance | -1.41e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | 0.242        |
# |    reward             | 0.0009915162 |
# |    std                | 1.01         |
# |    value_loss         | 0.0344       |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 327       |
# |    iterations         | 200       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -2.87     |
# |    explained_variance | -1.01e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -0.339    |
# |    reward             | 0.0       |
# |    std                | 1.01      |
# |    value_loss         | 0.0166    |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 323          |
# |    iterations         | 300          |
# |    time_elapsed       | 4            |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -2.88        |
# |    explained_variance | -1.66e+04    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | -0.619       |
# |    reward             | -0.000371669 |
# |    std                | 1.02         |
# |    value_loss         | 0.0165       |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 315           |
# |    iterations         | 400           |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -2.87         |
# |    explained_variance | -205          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 399           |
# |    policy_loss        | -0.124        |
# |    reward             | 0.00026209716 |
# |    std                | 1.02          |
# |    value_loss         | 0.00303       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 306           |
# |    iterations         | 500           |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 2500          |
# | train/                |               |
# |    entropy_loss       | -2.87         |
# |    explained_variance | -11.9         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 499           |
# |    policy_loss        | 0.209         |
# |    reward             | -8.544352e-05 |
# |    std                | 1.02          |
# |    value_loss         | 0.00876       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 294           |
# |    iterations         | 600           |
# |    time_elapsed       | 10            |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -2.89         |
# |    explained_variance | -1.23e+04     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | 0.0149        |
# |    reward             | 0.00044730835 |
# |    std                | 1.03          |
# |    value_loss         | 0.00197       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 298           |
# |    iterations         | 700           |
# |    time_elapsed       | 11            |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -2.91         |
# |    explained_variance | -1.33e+05     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | 0.467         |
# |    reward             | -3.826294e-05 |
# |    std                | 1.04          |
# |    value_loss         | 0.0278        |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 303            |
# |    iterations         | 800            |
# |    time_elapsed       | 13             |
# |    total_timesteps    | 4000           |
# | train/                |                |
# |    entropy_loss       | -2.91          |
# |    explained_variance | -2.3e+03       |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 799            |
# |    policy_loss        | -0.0419        |
# |    reward             | -0.00058164453 |
# |    std                | 1.04           |
# |    value_loss         | 0.00115        |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 305           |
# |    iterations         | 900           |
# |    time_elapsed       | 14            |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -2.91         |
# |    explained_variance | -3.61e+03     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | 0.502         |
# |    reward             | -0.0004110299 |
# |    std                | 1.04          |
# |    value_loss         | 0.0172        |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 306          |
# |    iterations         | 1000         |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -2.94        |
# |    explained_variance | -23.9        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | -0.0638      |
# |    reward             | -0.001612323 |
# |    std                | 1.05         |
# |    value_loss         | 0.000703     |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 302          |
# |    iterations         | 1100         |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -2.95        |
# |    explained_variance | -7.83e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | 0.226        |
# |    reward             | -0.000124775 |
# |    std                | 1.06         |
# |    value_loss         | 0.00601      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 301           |
# |    iterations         | 1200          |
# |    time_elapsed       | 19            |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -2.97         |
# |    explained_variance | -181          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1199          |
# |    policy_loss        | 0.0621        |
# |    reward             | -0.0016887977 |
# |    std                | 1.07          |
# |    value_loss         | 0.00125       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 298           |
# |    iterations         | 1300          |
# |    time_elapsed       | 21            |
# |    total_timesteps    | 6500          |
# | train/                |               |
# |    entropy_loss       | -2.99         |
# |    explained_variance | -12.6         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1299          |
# |    policy_loss        | -0.0178       |
# |    reward             | -9.140613e-05 |
# |    std                | 1.08          |
# |    value_loss         | 7.15e-05      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 295          |
# |    iterations         | 1400         |
# |    time_elapsed       | 23           |
# |    total_timesteps    | 7000         |
# | train/                |              |
# |    entropy_loss       | -3           |
# |    explained_variance | -308         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1399         |
# |    policy_loss        | -0.153       |
# |    reward             | -7.06201e-05 |
# |    std                | 1.09         |
# |    value_loss         | 0.00846      |
# ----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 293      |
# |    iterations         | 1500     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | -55.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.442   |
# |    reward             | 0.0      |
# |    std                | 1.09     |
# |    value_loss         | 0.024    |
# ------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 292           |
# |    iterations         | 1600          |
# |    time_elapsed       | 27            |
# |    total_timesteps    | 8000          |
# | train/                |               |
# |    entropy_loss       | -3.04         |
# |    explained_variance | -1.33e+04     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1599          |
# |    policy_loss        | 0.385         |
# |    reward             | 0.00035654753 |
# |    std                | 1.1           |
# |    value_loss         | 0.0188        |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 291          |
# |    iterations         | 1700         |
# |    time_elapsed       | 29           |
# |    total_timesteps    | 8500         |
# | train/                |              |
# |    entropy_loss       | -3.06        |
# |    explained_variance | -3.47e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1699         |
# |    policy_loss        | -0.0396      |
# |    reward             | 0.0008329041 |
# |    std                | 1.12         |
# |    value_loss         | 0.00102      |
# ----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 289          |
# |    iterations         | 1800         |
# |    time_elapsed       | 31           |
# |    total_timesteps    | 9000         |
# | train/                |              |
# |    entropy_loss       | -3.07        |
# |    explained_variance | -148         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1799         |
# |    policy_loss        | -0.0696      |
# |    reward             | 0.0030739245 |
# |    std                | 1.12         |
# |    value_loss         | 0.00255      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 288           |
# |    iterations         | 1900          |
# |    time_elapsed       | 32            |
# |    total_timesteps    | 9500          |
# | train/                |               |
# |    entropy_loss       | -3.08         |
# |    explained_variance | -72           |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1899          |
# |    policy_loss        | -0.225        |
# |    reward             | -0.0034534042 |
# |    std                | 1.13          |
# |    value_loss         | 0.00539       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 287           |
# |    iterations         | 2000          |
# |    time_elapsed       | 34            |
# |    total_timesteps    | 10000         |
# | train/                |               |
# |    entropy_loss       | -3.1          |
# |    explained_variance | -979          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1999          |
# |    policy_loss        | -0.0691       |
# |    reward             | 0.00062483904 |
# |    std                | 1.14          |
# |    value_loss         | 0.00111       |
# -----------------------------------------
# ======a2c Validation from:  2022-07-29 to  2022-10-27
# a2c Sharpe Ratio:  -0.27975691027167676
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/ddpg\ddpg_189_1
# day: 4343, episode: 5
# begin_total_asset: 2000.00
# end_total_asset: 9770.30
# total_reward: 7770.30
# total_cost: 1.99
# total_trades: 8686
# Sharpe: 0.569
# =================================
# ======ddpg Validation from:  2022-07-29 to  2022-10-27
# ddpg Sharpe Ratio:  -0.13896977122811074
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/td3\td3_189_1
# ======td3 Validation from:  2022-07-29 to  2022-10-27
# td3 Sharpe Ratio:  -0.13896977122811074
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/sac\sac_189_1
# day: 4343, episode: 10
# begin_total_asset: 2000.00
# end_total_asset: 1180.42
# total_reward: -819.58
# total_cost: 2896.91
# total_trades: 6922
# Sharpe: -0.076
# =================================
# ======sac Validation from:  2022-07-29 to  2022-10-27
# sac Sharpe Ratio:  -0.1763123850063852
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/ppo\ppo_189_1
# --------------------------------------
# | time/              |               |
# |    fps             | 472           |
# |    iterations      | 1             |
# |    time_elapsed    | 4             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | 0.00091728976 |
# --------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 441            |
# |    iterations           | 2              |
# |    time_elapsed         | 9              |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | 0.005733074    |
# |    clip_fraction        | 0.0432         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.84          |
# |    explained_variance   | -16.5          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0391        |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -0.00939       |
# |    reward               | -0.00031910485 |
# |    std                  | 1              |
# |    value_loss           | 0.0396         |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 429            |
# |    iterations           | 3              |
# |    time_elapsed         | 14             |
# |    total_timesteps      | 6144           |
# | train/                  |                |
# |    approx_kl            | 0.0042054006   |
# |    clip_fraction        | 0.0284         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.85          |
# |    explained_variance   | -8.87          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0465        |
# |    n_updates            | 20             |
# |    policy_gradient_loss | -0.00637       |
# |    reward               | -0.00012477803 |
# |    std                  | 1.01           |
# |    value_loss           | 0.0159         |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 426           |
# |    iterations           | 4             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.0068267337  |
# |    clip_fraction        | 0.0497        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | -4.47         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.041        |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.0111       |
# |    reward               | 0.00012428465 |
# |    std                  | 1.01          |
# |    value_loss           | 0.00688       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 422          |
# |    iterations           | 5            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0043503847 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -6.99        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0359      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00948     |
# |    reward               | 0.0          |
# |    std                  | 1.01         |
# |    value_loss           | 0.00406      |
# ------------------------------------------
# ======ppo Validation from:  2022-07-29 to  2022-10-27
# ppo Sharpe Ratio:  -0.2674985590516921
# ======Best Model Retraining from:  2005-04-27 to  2022-10-27
# ======Trading from:  2022-10-27 to  2023-01-30
# ============================================
# turbulence_threshold:  20.564223074924595
# ======Model training from:  2005-04-27 to  2022-10-27
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/a2c\a2c_252_1
# ----------------------------------------
# | time/                 |              |
# |    fps                | 339          |
# |    iterations         | 100          |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -2.86        |
# |    explained_variance | -782         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | -0.312       |
# |    reward             | 0.0006102139 |
# |    std                | 1.01         |
# |    value_loss         | 0.00918      |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 342            |
# |    iterations         | 200            |
# |    time_elapsed       | 2              |
# |    total_timesteps    | 1000           |
# | train/                |                |
# |    entropy_loss       | -2.88          |
# |    explained_variance | -1.47e+03      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 199            |
# |    policy_loss        | 0.0478         |
# |    reward             | -0.00010973987 |
# |    std                | 1.02           |
# |    value_loss         | 0.00395        |
# ------------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 339            |
# |    iterations         | 300            |
# |    time_elapsed       | 4              |
# |    total_timesteps    | 1500           |
# | train/                |                |
# |    entropy_loss       | -2.9           |
# |    explained_variance | -1.64e+03      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 299            |
# |    policy_loss        | 0.091          |
# |    reward             | -0.00014107775 |
# |    std                | 1.03           |
# |    value_loss         | 0.00143        |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 336          |
# |    iterations         | 400          |
# |    time_elapsed       | 5            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -2.93        |
# |    explained_variance | -92.3        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.0784       |
# |    reward             | 0.0004118904 |
# |    std                | 1.05         |
# |    value_loss         | 0.00208      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 330           |
# |    iterations         | 500           |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 2500          |
# | train/                |               |
# |    entropy_loss       | -2.95         |
# |    explained_variance | -84.2         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 499           |
# |    policy_loss        | 0.571         |
# |    reward             | 0.00043582305 |
# |    std                | 1.06          |
# |    value_loss         | 0.0351        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 328           |
# |    iterations         | 600           |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -2.98         |
# |    explained_variance | -192          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | -0.385        |
# |    reward             | 0.00074551394 |
# |    std                | 1.07          |
# |    value_loss         | 0.0084        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 327           |
# |    iterations         | 700           |
# |    time_elapsed       | 10            |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -2.99         |
# |    explained_variance | -47.9         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | 0.284         |
# |    reward             | -5.739441e-05 |
# |    std                | 1.08          |
# |    value_loss         | 0.0104        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 324           |
# |    iterations         | 800           |
# |    time_elapsed       | 12            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -3            |
# |    explained_variance | -1.08e+03     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | 0.45          |
# |    reward             | -0.0010884765 |
# |    std                | 1.09          |
# |    value_loss         | 0.0355        |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 324            |
# |    iterations         | 900            |
# |    time_elapsed       | 13             |
# |    total_timesteps    | 4500           |
# | train/                |                |
# |    entropy_loss       | -3             |
# |    explained_variance | -1.32e+03      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 899            |
# |    policy_loss        | 0.253          |
# |    reward             | -0.00047621236 |
# |    std                | 1.09           |
# |    value_loss         | 0.0142         |
# ------------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 323       |
# |    iterations         | 1000      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -3.01     |
# |    explained_variance | -6.04e+03 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -0.206    |
# |    reward             | 0.0       |
# |    std                | 1.09      |
# |    value_loss         | 0.0189    |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 321           |
# |    iterations         | 1100          |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 5500          |
# | train/                |               |
# |    entropy_loss       | -3.02         |
# |    explained_variance | -142          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1099          |
# |    policy_loss        | -0.154        |
# |    reward             | 3.5038574e-05 |
# |    std                | 1.1           |
# |    value_loss         | 0.00262       |
# -----------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 322      |
# |    iterations         | 1200     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | -342     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.105    |
# |    reward             | 0.0      |
# |    std                | 1.11     |
# |    value_loss         | 0.00403  |
# ------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 321           |
# |    iterations         | 1300          |
# |    time_elapsed       | 20            |
# |    total_timesteps    | 6500          |
# | train/                |               |
# |    entropy_loss       | -3.06         |
# |    explained_variance | -61.8         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1299          |
# |    policy_loss        | 0.0195        |
# |    reward             | -2.679756e-05 |
# |    std                | 1.12          |
# |    value_loss         | 0.000187      |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 321          |
# |    iterations         | 1400         |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 7000         |
# | train/                |              |
# |    entropy_loss       | -3.08        |
# |    explained_variance | -822         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1399         |
# |    policy_loss        | 0.0183       |
# |    reward             | 0.0003855194 |
# |    std                | 1.13         |
# |    value_loss         | 0.0032       |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 320            |
# |    iterations         | 1500           |
# |    time_elapsed       | 23             |
# |    total_timesteps    | 7500           |
# | train/                |                |
# |    entropy_loss       | -3.09          |
# |    explained_variance | -238           |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1499           |
# |    policy_loss        | 0.0896         |
# ...
# |    explained_variance | -259           |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 499            |
# |    policy_loss        | 0.428          |
# |    reward             | -3.2431184e-05 |
# |    std                | 1.01           |
# |    value_loss         | 0.0179         |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 322           |
# |    iterations         | 600           |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -2.88         |
# |    explained_variance | -507          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 599           |
# |    policy_loss        | 0.203         |
# |    reward             | 0.00051059446 |
# |    std                | 1.02          |
# |    value_loss         | 0.0359        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 322           |
# |    iterations         | 700           |
# |    time_elapsed       | 10            |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -2.89         |
# |    explained_variance | -5.41e+03     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 699           |
# |    policy_loss        | -0.15         |
# |    reward             | -3.826294e-05 |
# |    std                | 1.03          |
# |    value_loss         | 0.00708       |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 319           |
# |    iterations         | 800           |
# |    time_elapsed       | 12            |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -2.92         |
# |    explained_variance | -8.77e+03     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 799           |
# |    policy_loss        | 0.182         |
# |    reward             | -0.0030496418 |
# |    std                | 1.04          |
# |    value_loss         | 0.0176        |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 317          |
# |    iterations         | 900          |
# |    time_elapsed       | 14           |
# |    total_timesteps    | 4500         |
# | train/                |              |
# |    entropy_loss       | -2.93        |
# |    explained_variance | -1.15e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 899          |
# |    policy_loss        | 0.0383       |
# |    reward             | 0.0006176575 |
# |    std                | 1.05         |
# |    value_loss         | 0.0014       |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 315         |
# |    iterations         | 1000        |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 5000        |
# | train/                |             |
# |    entropy_loss       | -2.96       |
# |    explained_variance | -145        |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 999         |
# |    policy_loss        | -0.0659     |
# |    reward             | 0.002127832 |
# |    std                | 1.06        |
# |    value_loss         | 0.00133     |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 301          |
# |    iterations         | 1100         |
# |    time_elapsed       | 18           |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -2.97        |
# |    explained_variance | -2.03e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | 0.297        |
# |    reward             | 0.0050780983 |
# |    std                | 1.07         |
# |    value_loss         | 0.0171       |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 303           |
# |    iterations         | 1200          |
# |    time_elapsed       | 19            |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -2.97         |
# |    explained_variance | -1.23e+03     |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1199          |
# |    policy_loss        | -0.0267       |
# |    reward             | -0.0004403801 |
# |    std                | 1.07          |
# |    value_loss         | 0.00113       |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 304          |
# |    iterations         | 1300         |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 6500         |
# | train/                |              |
# |    entropy_loss       | -2.98        |
# |    explained_variance | -128         |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1299         |
# |    policy_loss        | -0.036       |
# |    reward             | 0.0004645755 |
# |    std                | 1.08         |
# |    value_loss         | 0.00108      |
# ----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 304            |
# |    iterations         | 1400           |
# |    time_elapsed       | 23             |
# |    total_timesteps    | 7000           |
# | train/                |                |
# |    entropy_loss       | -3.01          |
# |    explained_variance | -2.37e+03      |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1399           |
# |    policy_loss        | -0.0368        |
# |    reward             | -0.00035119514 |
# |    std                | 1.09           |
# |    value_loss         | 0.000946       |
# ------------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 304          |
# |    iterations         | 1500         |
# |    time_elapsed       | 24           |
# |    total_timesteps    | 7500         |
# | train/                |              |
# |    entropy_loss       | -3.02        |
# |    explained_variance | -2.68e+03    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1499         |
# |    policy_loss        | 0.115        |
# |    reward             | -8.92992e-05 |
# |    std                | 1.1          |
# |    value_loss         | 0.00298      |
# ----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 308           |
# |    iterations         | 1600          |
# |    time_elapsed       | 25            |
# |    total_timesteps    | 8000          |
# | train/                |               |
# |    entropy_loss       | -3.04         |
# |    explained_variance | -4.99         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1599          |
# |    policy_loss        | -0.0772       |
# |    reward             | -8.676512e-05 |
# |    std                | 1.1           |
# |    value_loss         | 0.000448      |
# -----------------------------------------
# ------------------------------------------
# | time/                 |                |
# |    fps                | 312            |
# |    iterations         | 1700           |
# |    time_elapsed       | 27             |
# |    total_timesteps    | 8500           |
# | train/                |                |
# |    entropy_loss       | -3.08          |
# |    explained_variance | -116           |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1699           |
# |    policy_loss        | -0.0155        |
# |    reward             | -0.00010851449 |
# |    std                | 1.13           |
# |    value_loss         | 0.000482       |
# ------------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 315           |
# |    iterations         | 1800          |
# |    time_elapsed       | 28            |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -3.11         |
# |    explained_variance | -155          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1799          |
# |    policy_loss        | 0.00797       |
# |    reward             | -8.938598e-05 |
# |    std                | 1.15          |
# |    value_loss         | 0.000216      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 316           |
# |    iterations         | 1900          |
# |    time_elapsed       | 29            |
# |    total_timesteps    | 9500          |
# | train/                |               |
# |    entropy_loss       | -3.14         |
# |    explained_variance | -66.7         |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1899          |
# |    policy_loss        | -0.000224     |
# |    reward             | -0.0008255237 |
# |    std                | 1.16          |
# |    value_loss         | 0.0003        |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 317           |
# |    iterations         | 2000          |
# |    time_elapsed       | 31            |
# |    total_timesteps    | 10000         |
# | train/                |               |
# |    entropy_loss       | -3.18         |
# |    explained_variance | -506          |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1999          |
# |    policy_loss        | -0.23         |
# |    reward             | -0.0020889048 |
# |    std                | 1.19          |
# |    value_loss         | 0.00499       |
# -----------------------------------------
# ======a2c Validation from:  2024-08-01 to  2024-10-30
# a2c Sharpe Ratio:  -0.11332502241848351
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/ddpg\ddpg_693_1
# day: 4847, episode: 5
# begin_total_asset: 2000.00
# end_total_asset: 30965.63
# total_reward: 28965.63
# total_cost: 1.98
# total_trades: 4847
# Sharpe: 0.768
# =================================
# ======ddpg Validation from:  2024-08-01 to  2024-10-30
# ddpg Sharpe Ratio:  0.203790980853312
# ======td3 Training========
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.0001}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/td3\td3_693_1
# ======td3 Validation from:  2024-08-01 to  2024-10-30
# td3 Sharpe Ratio:  0.0
# ======sac Training========
# {'batch_size': 64, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/sac\sac_693_1
# day: 4847, episode: 10
# begin_total_asset: 2000.00
# end_total_asset: 1212.03
# total_reward: -787.97
# total_cost: 2976.02
# total_trades: 7832
# Sharpe: -0.052
# =================================
# ======sac Validation from:  2024-08-01 to  2024-10-30
# sac Sharpe Ratio:  0.28854260787857483
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device
# Logging to ../finrl_outputs/tensorboard_logs/ppo\ppo_693_1
# --------------------------------------
# | time/              |               |
# |    fps             | 427           |
# |    iterations      | 1             |
# |    time_elapsed    | 4             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | 0.00081536866 |
# --------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 404           |
# |    iterations           | 2             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.0051714387  |
# |    clip_fraction        | 0.0487        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | -4.48         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0181       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00827      |
# |    reward               | -0.0002832947 |
# |    std                  | 0.995         |
# |    value_loss           | 0.101         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 396           |
# |    iterations           | 3             |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0046899645  |
# |    clip_fraction        | 0.0395        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | -7.41         |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0315       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00748      |
# |    reward               | -8.530974e-05 |
# |    std                  | 0.996         |
# |    value_loss           | 0.0213        |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 392            |
# |    iterations           | 4              |
# |    time_elapsed         | 20             |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | 0.0053399936   |
# |    clip_fraction        | 0.0391         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.82          |
# |    explained_variance   | -6.17          |
# |    learning_rate        | 0.00025        |
# |    loss                 | -0.0298        |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -0.0104        |
# |    reward               | -4.3978802e-05 |
# |    std                  | 0.988          |
# |    value_loss           | 0.0128         |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 390           |
# |    iterations           | 5             |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.003822732   |
# |    clip_fraction        | 0.0195        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.81         |
# |    explained_variance   | -8.8          |
# |    learning_rate        | 0.00025       |
# |    loss                 | -0.0511       |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00962      |
# |    reward               | -0.0011218431 |
# |    std                  | 0.989         |
# |    value_loss           | 0.00541       |
# -------------------------------------------
# ======ppo Validation from:  2024-08-01 to  2024-10-30
# ppo Sharpe Ratio:  -0.11149119591865932
# ======Best Model Retraining from:  2005-04-27 to  2024-10-30
# ======Trading from:  2024-10-30 to  2025-02-03
# Ensemble Strategy took:  44.83085780938466  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2022-04-28  2022-07-29       DDPG  -0.095179  -0.268582         0.0
# 1  189  2022-07-29  2022-10-27       DDPG  -0.279757  -0.267499    -0.13897
# 2  252  2022-10-27  2023-01-30        SAC    0.16972   0.124704    0.164164
# 3  315  2023-01-30  2023-05-01        PPO   0.074438   0.206939      0.1419
# 4  378  2023-05-01  2023-08-01       DDPG   0.511703   0.136327    0.565514
# 5  441  2023-08-01  2023-10-30       DDPG  -0.421838  -0.454611         0.0
# 6  504  2023-10-30  2024-01-31        TD3   0.836238   0.352219         0.0
# 7  567  2024-01-31  2024-05-01        SAC  -0.079719   0.058663    0.181643
# 8  630  2024-05-01  2024-08-01        TD3   0.093489   0.024915    0.340901
# 9  693  2024-08-01  2024-10-30        SAC  -0.113325  -0.111491    0.203791
#
#   SAC Sharpe TD3 Sharpe
# 0  -0.077449  -0.033395
# 1  -0.176312   -0.13897
# 2    0.28474        0.0
# 3   0.191064     0.1419
# 4   0.381936   0.480617
# 5  -0.514285  -0.421838
# 6   0.614983   0.859178
# 7   0.206038   0.181643
# 8   0.396477   0.478563
# 9   0.288543        0.0

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Collect account value logs
df_account_value = pd.DataFrame()
for i in range(rebalance_window + validation_window, len(processed.date.unique()) + 1, rebalance_window):
    path = os.path.join(RESULTS_DIR, f"account_value_trade_ensemble_{i}.csv")
    if os.path.exists(path):
        temp = pd.read_csv(path)
        print(f"[✓] Loaded {path} with columns: {temp.columns.tolist()}")
        df_account_value = pd.concat([df_account_value, temp], ignore_index=True)
    else:
        print(f"[!] File not found: {path}")

# Confirm expected column exists
if "account_value" not in df_account_value.columns:
    raise ValueError(f"[X] Column 'account_value' not found. Available columns: {df_account_value.columns.tolist()}")

# Compute Sharpe Ratio
returns = df_account_value["account_value"].pct_change(1)
sharpe = (252**0.5) * returns.mean() / returns.std()
print(f"Sharpe Ratio: {sharpe:.4f}")

# Plot
df_account_value["date"] = pd.to_datetime(df_account_value["date"])
plt.figure(figsize=(14,6))
plt.plot(df_account_value["date"], df_account_value["account_value"], label="Portfolio Value")
plt.title("Portfolio Account Value Over Time")
plt.xlabel("Date")
plt.ylabel("Account Value")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [✓] Loaded ../finrl_outputs\results\account_value_trade_ensemble_126.csv with columns: ['account_value', 'date', 'daily_return']
# [✓] Loaded ../finrl_outputs\results\account_value_trade_ensemble_189.csv with columns: ['account_value', 'date', 'daily_return']
# [✓] Loaded ../finrl_outputs\results\account_value_trade_ensemble_252.csv with columns: ['account_value', 'date', 'daily_return']
# [✓] Loaded ../finrl_outputs\results\account_value_trade_ensemble_315.csv with columns: ['account_value', 'date', 'daily_return']
# [✓] Loaded ../finrl_outputs\results\account_value_trade_ensemble_378.csv with columns: ['account_value', 'date', 'daily_return']
# [✓] Loaded ../finrl_outputs\results\account_value_trade_ensemble_441.csv with columns: ['account_value', 'date', 'daily_return']
# [✓] Loaded ../finrl_outputs\results\account_value_trade_ensemble_504.csv with columns: ['account_value', 'date', 'daily_return']
# [✓] Loaded ../finrl_outputs\results\account_value_trade_ensemble_567.csv with columns: ['account_value', 'date', 'daily_return']
# [✓] Loaded ../finrl_outputs\results\account_value_trade_ensemble_630.csv with columns: ['account_value', 'date', 'daily_return']
# [✓] Loaded ../finrl_outputs\results\account_value_trade_ensemble_693.csv with columns: ['account_value', 'date', 'daily_return']
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_756.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_819.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_882.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_945.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1008.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1071.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1134.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1197.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1260.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1323.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1386.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1449.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1512.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1575.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1638.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1701.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1764.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1827.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1890.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_1953.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2016.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2079.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2142.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2205.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2268.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2331.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2394.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2457.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2520.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2583.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2646.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2709.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2772.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2835.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2898.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_2961.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3024.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3087.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3150.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3213.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3276.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3339.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3402.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3465.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3528.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3591.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3654.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3717.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3780.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3843.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3906.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_3969.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4032.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4095.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4158.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4221.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4284.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4347.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4410.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4473.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4536.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4599.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4662.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4725.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4788.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4851.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4914.csv
# [!] File not found: ../finrl_outputs\results\account_value_trade_ensemble_4977.csv
# Sharpe Ratio: 0.7077

# %% [markdown]
# # backtest status

# %%
# === Part X: BACKTEST METRICS & BASELINE COMPARISON ===

from finrl.plot import backtest_stats, get_baseline
from datetime import datetime
import os

# Save timestamped summary
now = datetime.now().strftime('%Y%m%d-%Hh%M')

# Compute performance statistics of our portfolio
print("============== Get Backtest Results ==============")
perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv(f"finrl_outputs/summary_perf_{now}.csv")

# === Get baseline index stats (Dow Jones Index) ===
print("============== Get Baseline Stats ==============")
df_dji_raw = get_baseline(
    ticker="^DJI",
    start=df_account_value.loc[0, 'date'],
    end=df_account_value.loc[len(df_account_value)-1, 'date']
)

# Normalize baseline to same starting amount
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_raw['close'] / df_dji_raw['close'].iloc[0] * env_kwargs["initial_amount"]

# Save both outputs
df_account_value.to_csv("finrl_outputs/df_account_value.csv", index=False)
df_dji.to_csv("finrl_outputs/df_dji.csv", index=False)

# Also return DataFrame for reuse
df_dji = df_dji.set_index('date')
df_account_value = df_account_value.set_index('date')

print("Saved: df_account_value.csv, df_dji.csv, and perf_stats CSV.")
# Out:
# ============== Get Backtest Results ==============
# Annual return          0.081429
# Cumulative returns     0.216173
# Annual volatility      0.121156
# Sharpe ratio           0.707687
# Calmar ratio           0.652951
# Stability              0.652891
# Max drawdown          -0.124710
# Omega ratio            1.155867
# Sortino ratio          1.034584
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.039027
# Daily value at risk   -0.014924
# dtype: float64
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[30], line 14
#      12 perf_stats_all = backtest_stats(account_value=df_account_value)
#      13 perf_stats_all = pd.DataFrame(perf_stats_all)
# ---> 14 perf_stats_all.to_csv(f"finrl_outputs/summary_perf_{now}.csv")
#      16 # === Get baseline index stats (Dow Jones Index) ===
#      17 print("============== Get Baseline Stats ==============")
#
# File c:\Users\user\anaconda3\envs\finrl_etf_agent\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\user\anaconda3\envs\finrl_etf_agent\lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\user\anaconda3\envs\finrl_etf_agent\lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\user\anaconda3\envs\finrl_etf_agent\lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\user\anaconda3\envs\finrl_etf_agent\lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\user\anaconda3\envs\finrl_etf_agent\lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'finrl_outputs'

# %% [markdown]
# # backtestPlot

# %%
# === FINAL COMPARISON: ENSEMBLE VS SPY ===

import matplotlib.pyplot as plt

# Create result folder if not exists
os.makedirs(RESULTS_DIR, exist_ok=True)

# Create result DataFrame from account value
df_result_ensemble = pd.DataFrame({
    "date": df_account_value["date"],
    "ensemble": df_account_value["account_value"]
})
df_result_ensemble.set_index("date", inplace=True)

# Save ensemble result
ensemble_path = os.path.join(RESULTS_DIR, "df_result_ensemble.csv")
df_result_ensemble.to_csv(ensemble_path)
print(f"Saved ensemble results to: {ensemble_path}")

# Download SPY baseline if not yet available
from finrl.plot import get_baseline

spy_baseline = get_baseline(
    ticker="SPY",
    start=df_account_value['date'].iloc[0],
    end=df_account_value['date'].iloc[-1]
)

# Normalize SPY value to start at same initial amount
df_spy = pd.DataFrame()
df_spy["date"] = df_account_value["date"]
df_spy["spy"] = spy_baseline["close"] / spy_baseline["close"].iloc[0] * env_kwargs["initial_amount"]
df_spy.set_index("date", inplace=True)

# Merge for comparison
result = pd.merge(df_result_ensemble, df_spy, left_index=True, right_index=True)
result.columns = ["ensemble", "spy"]

# Save final comparison CSV
comparison_path = os.path.join(RESULTS_DIR, "result_ensemble_vs_spy.csv")
result.to_csv(comparison_path)
print(f"Saved result comparison to: {comparison_path}")

# Plot comparison
plt.figure(figsize=(15, 5))
plt.plot(result.index, result["ensemble"], label="Ensemble Strategy", linewidth=2)
plt.plot(result.index, result["spy"], label="S&P 500 ETF (SPY)", linestyle="--")
plt.title("Performance Comparison: Ensemble vs SPY")
plt.xlabel("Date")
plt.ylabel("Portfolio Value")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Saved ensemble results to: ../finrl_outputs\results\df_result_ensemble.csv
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (629, 8)
# Saved result comparison to: ../finrl_outputs\results\result_ensemble_vs_spy.csv
